# %% [markdown]
# # Trine states

# %% [markdown]
# This notebook will introduce trine states and related discrimination tasks or communication protocols.

# %%
from toqito.states import trine

psi1, psi2, psi3 = trine()

# %%
print(trine())

# %%
# TODO Reverse trine
