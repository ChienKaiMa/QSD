# %% [markdown]
# #
# This notebook intends to record the experiments to test the scaling of CVXPY
# solvers in QSD problems.

# %% [markdown]
# # Please make the sentences more academic and professional

# %%
# bfs=True for basic solution
